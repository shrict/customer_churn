# %%
print('||','\u0950',' Om Namo Shivay','\u0950','||')
print('|| Shri ||')
# Out:
# || ॐ  Om Namo Shivay ॐ ||
# || Shri ||

# %%
# import various important libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Project for Customer Churn in Telecom Industry.

# %% [markdown]
# ##  1.Problem Definition

# %% [raw]
# We can increase the revenue of any company by :
#     1. Recruiting  New Customers
#     2. Retain the Existing Customers
#
# As customers increases profit increases.
#
# 1. Recruiting  new customers is difficult in telecom industry due to:
#     1. Saturated market
#     2.high cost due of Advertisisng and Marketting
#
# 2. Retain existing customers is easy because:
#     1.Lower cost ( no cost of advertisisng and marketing)
#     2.Loyalty Benefits
#
# Here We focus on retaining existing customers.
# Most common issue telecommunication industry faces is to retain customers and it is challenging task.
# for retaining existing customers we need to undersatnd what is Churning and what makes an customer churn

# %% [markdown]
# ## Churn

# %% [raw]
# Churn is number of subscribers disconnecting thier services over a given period of time.
# It can be expreesed as chrun rate.
#
# Churn Rate=  ((lost customers)/( Total customers at the begining)) *100
#
# Churn is due to :
#     1. Company Attributes
#     2.Customer Attributes
#
# Here We study the factors responsible for churning by using customer attributes.
# we try to understand customer behaviour and attributes useful in identifying characteristics of churners.

# %% [markdown]
# # 2. Data Gathering

# %%
# Import data set
# dataset is downloaded from kaggle

# %%
# Read the dataset

# %%
df=pd.read_excel(r'C:\Users\welcome\Desktop\telecom xustomer churn\archive\Telecom_chrun.xlsx')
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4286  4123-DVHPH    Male              0     Yes         No       9
# 3472  4840-ORQXB  Female              1      No         No      56
# 4064  0374-AACSZ  Female              0      No         No       1
# 1909  3750-YHRYO    Male              0     Yes        Yes       7
# 5341  2982-IHMFT  Female              1      No         No       1
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 4286          Yes           Yes     Fiber optic                  Yes  ...
# 3472          Yes           Yes     Fiber optic                   No  ...
# 4064          Yes            No             DSL                  Yes  ...
# 1909          Yes            No              No  No internet service  ...
# 5341          Yes           Yes     Fiber optic                   No  ...
#
#               StreamingTV      StreamingMovies        Contract  \
# ...

# %% [markdown]
# # 3. Explorartory Data Analysis Starts

# %%
# check shape of dataset
df.shape
# Out:
# (7043, 23)

# %%
# how does data looklike
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
 # 5 random rows
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6801  6668-CNMFP  Female              0     Yes        Yes      19
# 1495  4472-VESGY  Female              0     Yes        Yes      52
# 2029  6481-OGDOO    Male              0     Yes         No      67
# 5123  8020-BWHYL  Female              1      No         No      15
# 1071  3097-NNSPB  Female              0      No         No       2
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 6801          Yes           Yes     Fiber optic             No  ...
# 1495          Yes           Yes     Fiber optic            Yes  ...
# 2029          Yes            No     Fiber optic            Yes  ...
# 5123          Yes            No     Fiber optic             No  ...
# 1071          Yes            No             DSL             No  ...
#
#      StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 6801          No             Yes        One year              Yes
# ...

# %%
# Check datatype of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# Here  data type of 'Total charges' is Object (string).
# we need to convert it into numbers
df.TotalCharges.values
# Out:
# array([29.85, 1889.5, 108.15, ..., 346.45, 306.6, 6844.5], dtype=object)

# %%
# before  chnaging data type of Total Charges , we need to remove null values present in the form of "---" 
# following rows contain empty values in Total Charges column
df[pd.to_numeric(df.TotalCharges,errors='coerce').isnull()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
# here  only 11 rows out of 7043 are have null values,  we can remove them

# %%
df = df[df.TotalCharges!=' ']
df.shape
# Out:
# (7032, 23)

# %%
df.TotalCharges = pd.to_numeric(df.TotalCharges)
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# check missing value
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# numAdminTickets     0
# numTechTickets      0
# Churn               0
# dtype: int64

# %%
# Recheck the datatypes of columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %%
# check 5 point summary of dataset
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges  \
# count    7032.000000  7032.000000     7032.000000   7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441
# std         0.368844    24.545260       30.085974   2266.771362
# min         0.000000     1.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.587500    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.862500   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000
#
#        numAdminTickets  numTechTickets
# count      7032.000000     7032.000000
# mean          0.514932        0.420222
# std           1.273921        1.250984
# min           0.000000        0.000000
# 25%           0.000000        0.000000
# 50%           0.000000        0.000000
# 75%           0.000000        0.000000
# max           5.000000        9.000000

# %%
# Check the Correlation between dataset features 
df.corr()
# Out:
#                  SeniorCitizen    tenure  MonthlyCharges  TotalCharges  \
# SeniorCitizen         1.000000  0.015683        0.219874      0.102411
# tenure                0.015683  1.000000        0.246862      0.825880
# MonthlyCharges        0.219874  0.246862        1.000000      0.651065
# TotalCharges          0.102411  0.825880        0.651065      1.000000
# numAdminTickets      -0.000621  0.000344        0.008717      0.007200
# numTechTickets        0.093121  0.214777        0.244920      0.283839
#
#                  numAdminTickets  numTechTickets
# SeniorCitizen          -0.000621        0.093121
# tenure                  0.000344        0.214777
# MonthlyCharges          0.008717        0.244920
# TotalCharges            0.007200        0.283839
# numAdminTickets         1.000000       -0.007820
# numTechTickets         -0.007820        1.000000

# %%
# Multivariate analysis using a correlation matrix and heatmap
correlation_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Multivariate Analysis - Correlation Matrix')
plt.show()

# %% [markdown]
# # 3.1 Univariate Analysis

# %%
## Categorical columns univariate analysis

# %%
sns.countplot(df['SeniorCitizen'])
print(df['SeniorCitizen'].value_counts())
# majority of customers are not senior citizens
# Out:
# 0    5890
# 1    1142
# Name: SeniorCitizen, dtype: int64
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df1['Partner'])
print(df['Partner'].value_counts())
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No     3639
# Yes    3393
# Name: Partner, dtype: int64

# %%
sns.countplot(df['Dependents'])
print(df['Dependents'].value_counts())
#Majority of cusomers are have no dependency
# Out:
# No     4933
# Yes    2099
# Name: Dependents, dtype: int64
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['InternetService'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['InternetService'].value_counts())
# Out:
# Fiber optic    3096
# DSL            2416
# No             1520
# Name: InternetService, dtype: int64

# %%
df['PhoneService'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['PhoneService'].value_counts())
# Out:
# Yes    6352
# No      680
# Name: PhoneService, dtype: int64

# %%
df['MultipleLines'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['MultipleLines'].value_counts())
# Out:
# No                  3385
# Yes                 2967
# No phone service     680
# Name: MultipleLines, dtype: int64

# %%
df['gender'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['gender'].value_counts())
# Out:
# Male      3549
# Female    3483
# Name: gender, dtype: int64

# %%
df['OnlineSecurity'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['OnlineSecurity'].value_counts())
# Out:
# No                     3497
# Yes                    2015
# No internet service    1520
# Name: OnlineSecurity, dtype: int64

# %%
df['OnlineBackup'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['OnlineBackup'].value_counts())
# Out:
# No                     3087
# Yes                    2425
# No internet service    1520
# Name: OnlineBackup, dtype: int64

# %%
df['DeviceProtection'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['DeviceProtection'].value_counts())
# Out:
# No                     3094
# Yes                    2418
# No internet service    1520
# Name: DeviceProtection, dtype: int64

# %%
df['TechSupport'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['TechSupport'].value_counts())
# Out:
# No                     3472
# Yes                    2040
# No internet service    1520
# Name: TechSupport, dtype: int64

# %%
df['StreamingMovies'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['StreamingMovies'].value_counts())
# Out:
# No                     2781
# Yes                    2731
# No internet service    1520
# Name: StreamingMovies, dtype: int64

# %%
df['StreamingTV'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['StreamingTV'].value_counts())
# Out:
# No                     2809
# Yes                    2703
# No internet service    1520
# Name: StreamingTV, dtype: int64

# %%
df['PaperlessBilling'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['PaperlessBilling'].value_counts())
# Out:
# Yes    4168
# No     2864
# Name: PaperlessBilling, dtype: int64

# %%
df['PaymentMethod'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['PaymentMethod'].value_counts())
# Out:
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: PaymentMethod, dtype: int64

# %%
df['Churn'].value_counts().plot(kind='pie',autopct='.% 02f')
print(df['Churn'].value_counts())
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# # 2. Univariate Analysis of Numerical feature

# %% [raw]
# 1. TEUNURE

# %%
plt.hist(df['tenure'],bins=72)
# Out:
# (array([613., 238., 200., 176., 133., 110., 131., 123., 119., 116.,  99.,
#         117., 109.,  76.,  99.,  80.,  87.,  97.,  73.,  71.,  63.,  90.,
#          85.,  94.,  79.,  79.,  72.,  57.,  72.,  72.,  65.,  69.,  64.,
#          65.,  88.,  50.,  65.,  59.,  56.,  64.,  70.,  65.,  65.,  51.,
#          61.,  74.,  68.,  64.,  66.,  68.,  68.,  80.,  70.,  68.,  64.,
#          80.,  65.,  67.,  60.,  76.,  76.,  70.,  72.,  80.,  76.,  89.,
#          98., 100.,  95., 119., 170., 362.]),
#  array([ 1.        ,  1.98611111,  2.97222222,  3.95833333,  4.94444444,
#          5.93055556,  6.91666667,  7.90277778,  8.88888889,  9.875     ,
#         10.86111111, 11.84722222, 12.83333333, 13.81944444, 14.80555556,
#         15.79166667, 16.77777778, 17.76388889, 18.75      , 19.73611111,
#         20.72222222, 21.70833333, 22.69444444, 23.68055556, 24.66666667,
#         25.65277778, 26.63888889, 27.625     , 28.61111111, 29.59722222,
# ...

# %%
sns.boxplot(df['tenure'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tenure'>

# %%
# sns.boxplot(df['T'])

# %%
# sns.boxenplot(df['tenure'])

# %%
sns.boxplot(df['MonthlyCharges'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MonthlyCharges'>

# %%
sns.boxplot(df['TotalCharges'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalCharges'>

# %%
sns.distplot(df1['TotalCharges'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='TotalCharges', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis of Dataset

# %%
sns.scatterplot(df['MonthlyCharges'],df['TotalCharges'],hue=df['Churn'])
# customers having having high monthly charges and less total charges are more prone to churn 
# Customers having high monthly charges as well as total charges are satisfied with company and less prone to churn.
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>

# %%
sns.scatterplot(df['tenure'],df['TotalCharges'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>

# %%
sns.scatterplot(df['tenure'],df['MonthlyCharges'],df['InternetService'])

# customers having low monthlyt charges prefer not to use any Internet service
# due to fibre optics internet service , monthly charges are going high
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>

# %%
sns.barplot(df['Churn'],df['TotalCharges']) 
# avg total charges of each churn and non churn categories
# higher the total charges lower is number of churning due to contract bond
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>

# %%
sns.barplot(df['Churn'],df['MonthlyCharges'],hue=df['SeniorCitizen']) 
# average monthly charges of each churn and non churn categories
# higher monthly charges , higher chances of churning
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='MonthlyCharges'>

# %%
sns.barplot(df1['Churn'],df1['tenure']) 
# more the tenure less chance of churning
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %%
sns.barplot(df1['InternetService'],df1['TotalCharges'])
# fiber optics service is costly which means that it is adds more to Total charges than any other internet service
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternetService', ylabel='TotalCharges'>

# %%
sns.barplot(df1['InternetService'],df1['MonthlyCharges'])
# Fiber optics service is costly and it contributes more in monthly charges
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternetService', ylabel='MonthlyCharges'>

# %%
sns.barplot(df1['Churn'],df1['tenure'])
# Higher is the tenure lower is the number of churners due to bond
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Churn', ylabel='tenure'>

# %%
# data visualize

# %%
sns.distplot(df1[df1['Churn']=='No']['MonthlyCharges'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.distplot(df1[df1['Churn']=='Yes']['MonthlyCharges'])
# Out:
# C:\Users\welcome\Downloads\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.heatmap(pd.crosstab(df1['Churn'],df1['SeniorCitizen']))
# pd.crosstab(df1['SeniorCitizen'],df1['Churn'])
# Out:
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='Churn'>

# %%
# sns.pairplot(df1,hue='Churn')
# plt.scatter(df[])
sns.pairplot(df)

# %%
tenure_churn_no = df[df.Churn=='No'].tenure
tenure_churn_yes = df[df.Churn=='Yes'].tenure

plt.xlabel("tenure")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")


plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['red','blue'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
tenure_churn_no = df[df.Churn=='No'].tenure
tenure_churn_yes = df[df.Churn=='Yes'].tenure

plt.xlabel("TotalCharges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")


plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=0.95, color=['red','blue'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %%
tenure_churn_no = df[df.Churn=='No'].tenure
tenure_churn_yes = df[df.Churn=='Yes'].tenure

plt.xlabel("MonthlyCharges")
plt.ylabel("Number Of Customers")
plt.title("Customer Churn Prediction Visualiztion")


plt.hist([tenure_churn_yes, tenure_churn_no], rwidth=.95, color=['red','blue'],label=['Churn=Yes','Churn=No'])
plt.legend()

# %% [markdown]
# # 4. Feature Engineering

# %%
# check Unique values in dataset from each column

# %%
def print_unique_col_values(df):
       for column in df:
            if df[column].dtypes=='object':
                print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(df)
# Out:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %%
# here 'No internet service' is same as 'No' . hence we replcae it by 'NO'.
# here 'No phone service' is same as 'No' . hence we replcae it by 'NO'

# %%
df.replace('No internet service','No',inplace=True)
df.replace('No phone service','No',inplace=True)

# %%
print_unique_col_values(df)
# Out:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['No' 'Yes']
# StreamingTV: ['No' 'Yes']
# StreamingMovies: ['No' 'Yes']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn: ['No' 'Yes']

# %% [markdown]
# ## Encoding of features

# %%
# Computers only understands Numbers. So we need convert the datatype of all to Numerical format.

# %% [markdown]
# # One hot encoding

# %%
# Onehotencoding using pandas

# %%
df=pd.get_dummies(df,columns=['gender','Partner','Dependents','PhoneService','MultipleLines','OnlineSecurity','OnlineBackup',
                  'DeviceProtection','TechSupport','StreamingTV','StreamingMovies','PaperlessBilling','InternetService','Contract','PaymentMethod'],drop_first=True)
df.head()
# Out:
#    customerID  SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# 0  7590-VHVEG              0       1           29.85         29.85
# 1  5575-GNVDE              0      34           56.95       1889.50
# 2  3668-QPYBK              0       2           53.85        108.15
# 3  7795-CFOCW              0      45           42.30       1840.75
# 4  9237-HQITU              0       2           70.70        151.65
#
#    numAdminTickets  numTechTickets Churn  gender_Male  Partner_Yes  ...  \
# 0                0               0    No            0            1  ...
# 1                0               0    No            1            0  ...
# 2                0               0   Yes            1            0  ...
# 3                0               3    No            1            0  ...
# 4                0               0   Yes            0            0  ...
#
#    StreamingTV_Yes  StreamingMovies_Yes  PaperlessBilling_Yes  \
# 0                0                    0                     1
# ...

# %%
for col in df:
    df['Churn'].replace({'Yes': 1,'No': 0},inplace=True)

# %%
for col in df:
    print(f'{col}: {df[col].unique()}')
# Out:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' ... '4801-JZAZL' '8361-LTMKD'
#  '3186-AJIEK']
# SeniorCitizen: [0 1]
# tenure: [ 1 34  2 45  8 22 10 28 62 13 16 58 49 25 69 52 71 21 12 30 47 72 17 27
#   5 46 11 70 63 43 15 60 18 66  9  3 31 50 64 56  7 42 35 48 29 65 38 68
#  32 55 37 36 41  6  4 33 67 23 57 61 14 20 53 40 59 24 44 19 54 51 26 39]
# MonthlyCharges: [29.85 56.95 53.85 ... 63.1  44.2  78.7 ]
# TotalCharges: [  29.85 1889.5   108.15 ...  346.45  306.6  6844.5 ]
# numAdminTickets: [0 1 5 2 4 3]
# numTechTickets: [0 3 2 4 1 6 5 7 8 9]
# Churn: [0 1]
# gender_Male: [0 1]
# Partner_Yes: [1 0]
# Dependents_Yes: [0 1]
# PhoneService_Yes: [0 1]
# MultipleLines_Yes: [0 1]
# OnlineSecurity_Yes: [0 1]
# OnlineBackup_Yes: [1 0]
# DeviceProtection_Yes: [0 1]
# TechSupport_Yes: [0 1]
# StreamingTV_Yes: [0 1]
# StreamingMovies_Yes: [0 1]
# PaperlessBilling_Yes: [1 0]
# InternetService_Fiber optic: [0 1]
# InternetService_No: [0 1]
# Contract_One year: [0 1]
# ...

# %%
df.sample(5)
# Out:
#       customerID  SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# 5319  9866-OCCKE              1      72          109.75       8075.35
# 36    6047-YHPVI              0       5           69.70        316.90
# 5525  1333-PBMXB              0      54           24.75       1342.15
# 6215  2446-BEGGB              1       6           98.25        560.60
# 6253  6128-DAFVY              0      56           44.85       2564.95
#
#       numAdminTickets  numTechTickets  Churn  gender_Male  Partner_Yes  ...  \
# 5319                0               0      0            0            1  ...
# 36                  0               0      1            1            0  ...
# 5525                4               0      0            0            1  ...
# 6215                0               0      1            0            0  ...
# 6253                0               0      0            0            0  ...
#
#       StreamingTV_Yes  StreamingMovies_Yes  PaperlessBilling_Yes  \
# ...

# %%
df.info()

# here datatype of all the columns is integer and float( numeric). we can apply algorithms.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   customerID                             7032 non-null   object
#  1   SeniorCitizen                          7032 non-null   int64
#  2   tenure                                 7032 non-null   int64
#  3   MonthlyCharges                         7032 non-null   float64
#  4   TotalCharges                           7032 non-null   float64
#  5   numAdminTickets                        7032 non-null   int64
#  6   numTechTickets                         7032 non-null   int64
#  7   Churn                                  7032 non-null   int64
#  8   gender_Male                            7032 non-null   uint8
#  9   Partner_Yes                            7032 non-null   uint8
# ...

# %% [markdown]
# # 5. Feature selection

# %% [raw]
# we need to select relevant features for model building
# We need to remove Customer Id column

# %%
df=df.drop(columns=['customerID'])
df
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  numAdminTickets  \
# 0                 0       1           29.85         29.85                0
# 1                 0      34           56.95       1889.50                0
# 2                 0       2           53.85        108.15                0
# 3                 0      45           42.30       1840.75                0
# 4                 0       2           70.70        151.65                0
# ...             ...     ...             ...           ...              ...
# 7038              0      24           84.80       1990.50                0
# 7039              0      72          103.20       7362.90                0
# 7040              0      11           29.60        346.45                0
# 7041              1       4           74.40        306.60                0
# 7042              0      66          105.65       6844.50                2
#
# ...

# %% [markdown]
# # Feature Engineering

# %%
# before applying algorithms on data, we can clearly says there are some columns which have different scale from others.
# we need to scale them on same scale for better accuarcy.
# divide data into indepedent and dependent column

# %%
#  x=INDEPEDENT FEATURES
#  y=INDEPEDENT FEATURES

# %%
x=df.drop(columns=['Churn'])
y=df['Churn']
x
# Out:
#       SeniorCitizen  tenure  MonthlyCharges  TotalCharges  numAdminTickets  \
# 0                 0       1           29.85         29.85                0
# 1                 0      34           56.95       1889.50                0
# 2                 0       2           53.85        108.15                0
# 3                 0      45           42.30       1840.75                0
# 4                 0       2           70.70        151.65                0
# ...             ...     ...             ...           ...              ...
# 7038              0      24           84.80       1990.50                0
# 7039              0      72          103.20       7362.90                0
# 7040              0      11           29.60        346.45                0
# 7041              1       4           74.40        306.60                0
# 7042              0      66          105.65       6844.50                2
#
#       numTechTickets  gender_Male  Partner_Yes  Dependents_Yes  \
# ...

# %% [markdown]
# # scaling using MinMax scaler

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_scaled.shape
# Out:
# (7032, 25)

# %%
'''Data preprocessment part is Complete.
Now we can split data for model building.'''
# Out:
# 'Data preprocessment part is Complete.\nNow we can split data for model building.'

# %%
df1['Churn'].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
((5163)/(5163+1869))*100
# Out:
# 73.42150170648463

# %%
''' here dataset is highly imbalanced. 73 % NO and 27% YES. we can split the data using stratification of output column.this can remove imabalancement in spliting.'''
# Out:
# ' here dataset is highly imbalanced. 73 % NO and 27% YES. we can split the data using stratification of output column.this can remove imabalancement in spliting.'

# %% [markdown]
# # Train Test Split

# %% [raw]
# ''' here dataset is highly imbalanced. 73 % NO and 27% YES. we can split the data using stratification of output column.this can remove imabalancement in spliting.'''

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=5,stratify=y)

# %%
x_train.shape
# Out:
# (5625, 25)

# %%
x_test.shape
# Out:
# (1407, 25)

# %%
x_train[:10]
# Out:
# array([[0.00000000e+00, 5.35211268e-01, 8.77114428e-01, 4.64095315e-01,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#         0.00000000e+00],
#        [0.00000000e+00, 1.69014085e-01, 6.14427861e-01, 1.16610893e-01,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
# ...

# %% [markdown]
# # 6. Model Building

# %% [markdown]
# ## 6.1 Logical Regression

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression().fit(x_train,y_train)
LR
# Out:
# LogisticRegression()

# %%
### Coefficients of  various attributes

# %%
LR.coef_
# Out:
# array([[ 2.49760503e-01, -3.94127581e+00,  8.07014088e-02,
#         -1.64388073e+00, -2.56782815e-01,  1.06259191e+01,
#         -1.05624571e-02, -6.04847532e-02, -1.35050863e-01,
#         -4.18309493e-01,  2.46702682e-01, -4.27900341e-01,
#         -3.05505170e-01, -1.74478952e-01, -1.58540758e-01,
#         -3.44814394e-02,  1.12561784e-01,  2.74873634e-01,
#          9.88300944e-01, -9.00865978e-01, -7.97035853e-01,
#         -1.87504925e+00, -8.25965033e-02,  2.48022890e-01,
#         -1.51110206e-01]])

# %%
y_pred=LR.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8443496801705757

# %%
import os
pickle.dump(LR, open('LR.pkl', 'wb'))

# %% [markdown]
# ## 6.2  Decision Tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2=dtc.predict(x_test)
y_pred2
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred2,y_test)
score
# Out:
# 0.8081023454157783

# %%
import os
pickle.dump(dtc, open('dtc.pkl', 'wb'))

# %% [markdown]
# # 6.3  ANN model building and training

# %%
import tensorflow as tf
from tensorflow import keras


model = keras.Sequential([
    keras.layers.Dense(25, input_shape=(25,), activation='relu'),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 176/176 [==============================] - 1s 2ms/step - loss: 0.5623 - accuracy: 0.7129
# Epoch 2/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.4161 - accuracy: 0.8060
# Epoch 3/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3617 - accuracy: 0.8375
# Epoch 4/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3272 - accuracy: 0.8540
# Epoch 5/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3123 - accuracy: 0.8629
# Epoch 6/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.8644
# Epoch 7/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.3022 - accuracy: 0.8629
# Epoch 8/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.8644
# Epoch 9/100
# 176/176 [==============================] - 0s 2ms/step - loss: 0.2971 - accuracy: 0.8644
# Epoch 10/100
# ...

# %% [markdown]
# # 7. Model evaluation

# %%
model.evaluate(x_test, y_test)
# Out:
# 44/44 [==============================] - 1s 2ms/step - loss: 0.3491 - accuracy: 0.8436
# [0.3490545153617859, 0.8436389565467834]

# %%
yp = model.predict(x_test)
yp[:5]
# Out:
# 44/44 [==============================] - 0s 1ms/step
# array([[8.1744080e-04],
#        [2.6361966e-05],
#        [1.3228758e-01],
#        [2.3331836e-02],
#        [7.1661341e-01]], dtype=float32)

# %%
y_pred_ann = []
for element in yp:
    if element > 0.5:
        y_pred_ann.append(1)
    else:
        y_pred_ann.append(0)

# %%
y_pred_ann[:10]
# Out:
# [0, 0, 0, 0, 1, 0, 0, 0, 1, 0]

# %%
y_test[:10]
# Out:
# 6973    0
# 2833    0
# 1591    0
# 4935    0
# 2674    0
# 4168    0
# 5602    0
# 4911    0
# 5638    1
# 6213    0
# Name: Churn, dtype: int64

# %% [markdown]
# ### model evaluation using Performance Metrics

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test,y_pred_ann))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      1033
#            1       0.69      0.74      0.72       374
#
#     accuracy                           0.84      1407
#    macro avg       0.80      0.81      0.80      1407
# weighted avg       0.85      0.84      0.85      1407

# %% [markdown]
# ### visualize using confusion matrix

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_pred_ann)

plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
y_test.shape
# Out:
# (1407,)

# %% [markdown]
# # Accuracy

# %%
(911+276)/(911+276+122+98)
# Out:
# 0.84363894811656

# %% [markdown]
# # Precision for 0 class. i.e. Precision for customers who did not churn

# %%
((911)/(911+122))
# Out:
# 0.8818973862536302

# %% [markdown]
# # Precision for 1 class. i.e. Precision for customers who actually churned

# %%
(276/(275+98))
# Out:
# 0.739946380697051

# %% [markdown]
# # Recall for 0 class

# %%
round(276/(276+122),2)
# Out:
# 0.69

# %% [markdown]
# # Recall for 1 Class

# %%
round(911/(911+98),2)
# Out:
# 0.9

# %% [markdown]
# # 8. Save the model

# %%
# model_version=1
# model.save(f'..\churn_models\models{model_version}')
# Out:
# INFO:tensorflow:Assets written to: ..\churn_models\models1\assets

# %%
import os

# %%
pickle.dump(model, open('model.pkl', 'wb'))
# Out:
# INFO:tensorflow:Assets written to: ram://d352ce0e-efc9-4871-918a-4dbb580fa5b7/assets

# %% [markdown]
# # 9. Conclusion

# %% [raw]
# 1. Accuracy of all above models is not very good.
# This may be due to:
#     1. We do not have enough data( only 7032 rows)
#     2. We do not have enough customer attributes.we need important personal attributes.
#     3. We do not have information related to company attriutes.
#  2. There is a lot of chance of Improvement in above models
